# %% [markdown]
# <a href="https://colab.research.google.com/github/CarlosCordova2023/PrimeraRedNeuronal_Python/blob/main/PrimeraRedNeuronal.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Tensorflow / Pytorch

# %%
import pandas as pd
datos=pd.read_csv("celsius.csv")

# %%
datos.head()
# Out:
#    celsius  fahrenheit
# 0      -40      -40.00
# 1      -10       14.00
# 2        0       32.00
# 3        8       46.66
# 4       22       71.55

# %%
X=datos["celsius"].values
y=datos["fahrenheit"].values

# %%
import tensorflow as tf

modelo=tf.keras.Sequential([
    tf.keras.layers.Input(shape=(1,)),#laentrada, los celsius: 1 solo dato
    tf.keras.layers.Dense(units=1), # la salida también es un dato. los grados fahrenheit

                            ])

modelo.compile(
    optimizer=tf.keras.optimizers.Adam(.1),
    loss="mean_squared_error"
)

# %%
entrenamiento=modelo.fit(X,y,epochs=1000)
# Out:
# Epoch 1/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step - loss: 4880.1035
# Epoch 2/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - loss: 4569.9233
# Epoch 3/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - loss: 4272.5562
# Epoch 4/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - loss: 3988.2019
# Epoch 5/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 3717.0413
# Epoch 6/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 3459.2126
# Epoch 7/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 3214.8210
# Epoch 8/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 60ms/step - loss: 2983.9329
# Epoch 9/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 58ms/step - loss: 2766.5703
# Epoch 10/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - loss: 2562.7109
# Epoch 11/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - loss: 2372.2839
# Epoch 12/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 57ms/step - loss: 2195.1689
# Epoch 13/1000
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 2031.1938
# Epoch 14/1000
# ...

# %%
import matplotlib.pyplot as plt

plt.xlabel("# Epoca")
plt.ylabel("Magnitud de la pérdida")
plt.plot(entrenamiento.history["loss"])

# %%
C = 1230
prediccion = modelo.predict([C])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-43-c4b1ca014b3f> in <cell line: 2>()
#       1 C = 1230
# ----> 2 prediccion = modelo.predict([C])
#
# /usr/local/lib/python3.10/dist-packages/keras/src/utils/traceback_utils.py in error_handler(*args, **kwargs)
#     120             # To get the full stack trace, call:
#     121             # `keras.config.disable_traceback_filtering()`
# --> 122             raise e.with_traceback(filtered_tb) from None
#     123         finally:
#     124             del filtered_tb
#
# /usr/local/lib/python3.10/dist-packages/keras/src/trainers/data_adapters/__init__.py in get_data_adapter(x, y, sample_weight, batch_size, steps_per_epoch, shuffle, class_weight)
#     118         # )
#     119     else:
# --> 120         raise ValueError(f"Unrecognized data type: x={x} (of type {type(x)})")
#     121
#     122
#
# ...

# %%
print(f"Predicción: {c} celsius son {prediccion[0]} fahrenheit")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-dc16cee5f7b2> in <cell line: 1>()
# ----> 1 prediccion = modelo.predict([cc])
#       2
#       3 print(f"Predicción: {c} celsius son {prediccion[0]} fahrenheit")
#
# NameError: name 'cc' is not defined

# %%
print(modelo.layers[0].get_weights())
# Out:
# [array([[0.44913924]], dtype=float32), array([0.], dtype=float32)]

# %%
#Calculo real para convertir de celsius a fahrenheit es:
#(C*1.8)+32

# %%
# BackPropagation / Propagación hacia atrás
